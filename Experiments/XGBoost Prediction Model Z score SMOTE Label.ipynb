# %%
# Import packages
import pandas as pd
import numpy as np
import math
import time

import xgboost as xgb
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline

from hyperopt import *
import pyspark 
import mlflow

import seaborn as sns

import warnings

# %%
# Import Data
train = pd.read_csv("..\\Predictive Models\\Datasets\\17zScoreSMOTE_0.75_newlabel.csv", delimiter=',')
test = pd.read_csv("..\\Predictive Models\\Datasets\\172zScore_newlabel.csv", delimiter=',')
validation = pd.read_csv("..\\Predictive Models\\Datasets\\18zScore_newlabel.csv", delimiter=',')
validation2 = pd.read_csv("..\\Predictive Models\\Datasets\\19zScore_newlabel.csv", delimiter=',')

# Define X and y
X_train = (train.drop(labels=["label"], axis=1))
y_train = train[["label"]]
X_test = test.drop(labels=["label","c28992r100"], axis=1)
y_test =test[["label"]]

X_val1 = validation.drop(labels=["label","c28992r100"], axis=1)
y_val1 = validation[["label"]]
X_val2 = validation2.drop(labels=["label","c28992r100"], axis=1)
y_val2 = validation2[["label"]]

# Make column list
columns = X_train.columns

X_train = X_train.to_numpy()
y_train = y_train.to_numpy()

# %% [markdown]
# # Define hyperopt settings

# %%
import warnings
warnings.filterwarnings("ignore")

start_time = time.time()
# Define objectives
def objective(params):
    classifier_type = params['type']
    del params['type']
    if classifier_type == 'XGB':
        clf = xgb.XGBClassifier(**params,
                                eval_metric='auc')
    else:
        return 0
    classifier = clf
    print(classifier)
    classifier.fit(X_train, y_train)
    pr_xgb = classifier.predict(X_train)
    accuracy = accuracy_score(y_train,pr_xgb)
    f1 = f1_score(y_train,pr_xgb)
    recall = recall_score(y_train,pr_xgb)
    print(accuracy, f1, recall)

    # Because fmin() tries to minimize the objective, this function must return the negative accuracy. 
    return {'loss': -accuracy, 'status': STATUS_OK}

# Define search space
space = hp.choice('classifier_type', [
        {
        "type": 'XGB',
        'eta':hp.choice('eta',np.arange(0.01,0.5,0.05)),
        'max_depth':hp.choice('max_depth',range(2,15)),
        'min_child_weight':hp.choice('min_child_weight',range(1,15)),
        'max_leaves':hp.choice('max_leaves',range(2,15)),
        'subsample':hp.choice('subsample', np.arange(0.1, 0.5, 0.05))}
])
    
with mlflow.start_run():
    best = fmin(
    fn=objective, 
    space=space,
    algo=tpe.suggest,
    max_evals=30, 
    verbose = 1,
    return_argmin=False)
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.01, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=4,
#               max_leaves=14, min_child_weight=7, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.8066553093931527
# 0.7216607281531223
# 0.5848411368915954
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.01, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=14,
#               max_leaves=6, min_child_weight=3, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.25000000000000006, tree_method=None,
#               validate_parameters=None, ...)
# 0.950445135047766
# 0.9386621891316675
# 0.8847374802173088
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.41000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=9, max_leaves=13,
#               min_child_weight=6, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9793050379886916
# 0.9752736251211438
# 0.9523086747679294
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.26, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=4,
#               max_leaves=14, min_child_weight=11, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9765205888594269
# 0.9718367822708988
# 0.9452470638321502
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.060000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=10, max_leaves=3,
#               min_child_weight=2, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.20000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9728655035707982
# 0.9673103296682292
# 0.9367509185647253
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.26, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=6,
#               max_leaves=11, min_child_weight=14, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9782043476277643
# 0.9739086255852161
# 0.9491573267684106
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.21000000000000002,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=4, max_leaves=12,
#               min_child_weight=11, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9754060159173709
# 0.9704599538354894
# 0.9426325093244732
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.31000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=4, max_leaves=12,
#               min_child_weight=14, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.9772464495298763
# 0.9727305354778751
# 0.9469176021990023
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.41000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=11, max_leaves=4,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.15000000000000002, tree_method=None,
#               validate_parameters=None, ...)
# 0.9761298933619447
# 0.9716407641631245
# 0.9541411766883544
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.16000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=5, max_leaves=8,
#               min_child_weight=11, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.20000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9745532287908867
# 0.9694047627563611
# 0.9406565539708835
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.060000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=5, max_leaves=5,
#               min_child_weight=12, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=0.1,
#               tree_method=None, validate_parameters=None, ...)
# 0.9543461403449623
# 0.9437504887012277
# 0.8936408481337171
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.46, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=14,
#               max_leaves=6, min_child_weight=8, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.25000000000000006, tree_method=None,
#               validate_parameters=None, ...)
# 0.9793922999272157
# 0.9755459275767853
# 0.959120399078196
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.46, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=13,
#               max_leaves=13, min_child_weight=9, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9815936806490702
# 0.9781210145286271
# 0.9600181399180001
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.11, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=11,
#               max_leaves=10, min_child_weight=7, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9783570560201813
# 0.9740961667643825
# 0.949513646586271
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.060000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=3, max_leaves=5,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.20000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9116472872444862
# 0.8853724430721729
# 0.7961665540634342
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.41000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=6, max_leaves=2,
#               min_child_weight=12, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.30000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9784681166692119
# 0.9742341072356665
# 0.9498329461633148
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.26, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=7,
#               max_leaves=5, min_child_weight=13, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.30000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9783967205376922
# 0.9741448675437742
# 0.9496061971883127
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.26, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=6,
#               max_leaves=6, min_child_weight=3, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.9783114418250438
# 0.9740404016426519
# 0.9494164684541273
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.11, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=4,
#               max_leaves=14, min_child_weight=7, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9646946129635543
# 0.9570462738209563
# 0.917741024905367
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.46, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=6,
#               max_leaves=10, min_child_weight=14, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.9784423347328297
# 0.9742019698587872
# 0.9497542781515794
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.46, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=13,
#               max_leaves=13, min_child_weight=8, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.25000000000000006, tree_method=None,
#               validate_parameters=None, ...)
# 0.9789460741052181
# 0.9750020015352951
# 0.9580329295042064
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=12, max_leaves=9,
#               min_child_weight=9, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9799277709136127
# 0.9760374271664216
# 0.9538403872317189
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=12, max_leaves=9,
#               min_child_weight=9, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9799277709136127
# 0.9760374271664216
# 0.9538403872317189
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=7,
#               min_child_weight=9, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9806913128756973
# 0.97697354417267
# 0.9557746948143898
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=7,
#               min_child_weight=9, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9806913128756973
# 0.97697354417267
# 0.9557746948143898
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=7,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9915554242219309
# 0.99005349342428
# 0.9806476691130875
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.21000000000000002,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=2, max_leaves=13,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None, subsample=0.1,
#               tree_method=None, validate_parameters=None, ...)
# 0.9538562835537028
# 0.9431295722802189
# 0.8927801275347296
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.16000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=7,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.15000000000000002, tree_method=None,
#               validate_parameters=None, ...)
# 0.9790809334647551
# 0.9749863643909034
# 0.951285990615369
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.31000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=4,
#               min_child_weight=5, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9813735425768847
# 0.9777952204874083
# 0.9569269498098085
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.46, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=8,
#               max_leaves=8, min_child_weight=10, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9786981708707749
# 0.9745298298115526
# 0.9508833954964877
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 30/30 [3:08:10<00:00, 376.36s/trial, best loss: -0.9915554242219309]
# --- 11293.34661436081 seconds ---

# %%
# Results
print(best)
# Out:
# {'eta': 0.36000000000000004, 'max_depth': 13, 'max_leaves': 7, 'min_child_weight': 1, 'subsample': 0.3500000000000001, 'type': 'XGB'}

# %%
# Fitting Randomforest to the Training set
classifier = xgb.XGBClassifier(eta = best['eta'],
                            max_depth = best['max_depth'],
                            min_child_weight = int(best['min_child_weight']),
                            max_leaves= int(best['max_leaves']),
                            subsample = best['subsample'],
                           n_jobs = -1,)
classifier.fit(X_train, y_train)
pr_xgb = classifier.predict(X_train)
accuracy = accuracy_score(y_train,pr_xgb)
f1 = f1_score(y_train,pr_xgb)
recall = recall_score(y_train,pr_xgb)
print(accuracy, f1, recall)
print(roc_auc_score(y_train, classifier.predict_proba(X_train)[:, 1]))
# Out:
# [05:27:16] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9915554242219309 0.99005349342428 0.9806476691130875
# 0.9997324554085495

# %% [markdown]
# # Results

# %%
# Make confusion matrixes, accuracy, recall and f1 score for testset
p_xgb = classifier.predict(X_test)
print("Accuracy:" + str(classifier.score(X_test, y_test)))
print("F1:" + str(f1_score(y_test,p_xgb)))
print("Recall:" + str(recall_score(y_test,p_xgb)))
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test,p_xgb),display_labels=classifier.classes_).plot()
plt.savefig('New Figures\con_test_xgb_z_smote.png', dpi=300)
plt.show()

# Make confusion matrixes, accuracy, recall and f1 score for validationset 1
pre_xgb = classifier.predict(X_val1)
print("Accuracy:" + str(classifier.score(X_val1, y_val1)))
print("F1:" + str(f1_score(y_val1,pre_xgb)))
print("Recall:" + str(recall_score(y_val1,pre_xgb)))
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_val1,pre_xgb),display_labels=classifier.classes_).plot()
plt.savefig('New Figures\con_val_xgb_z_smote.png', dpi=300)
plt.show()


# Make confusion matrixes, accuracy, recall and f1 score for validationset 2
pred_xgb = classifier.predict(X_val2)
print("Accuracy:" + str(classifier.score(X_val2, y_val2)))
print("F1:" + str(f1_score(y_val2, pred_xgb)))
print("Recall:" + str(recall_score(y_val2, pred_xgb)))
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_val2, pred_xgb),display_labels=classifier.classes_).plot()
plt.savefig('New Figures\con_val2_xgb_z_smote.png', dpi=300)
plt.show()
# Out:
# Accuracy:0.02878665590529997
# F1:0.0559623430962343
# Recall:1.0
# Accuracy:0.03404319621790236
# F1:0.06550829360997845
# Recall:0.9999203060248645
# Accuracy:0.02093904536658783
# F1:0.04084749198926811
# Recall:0.9998711007991751

# %%
print(roc_auc_score(y_test, classifier.predict_proba(X_test)[:, 1]))
print(roc_auc_score(y_val1, classifier.predict_proba(X_val1)[:, 1]))
print(roc_auc_score(y_val2, classifier.predict_proba(X_val2)[:, 1]))
# Out:
# 0.5220130996453258
# 0.49583827328842073
# 0.479320010214965

# %%
# Create feature importance plot
feat_importances = pd.Series(classifier.feature_importances_, index=columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.savefig('New Figures\import_xgb_z_smote.png', dpi=300, bbox_inches = "tight")

# %% [markdown]
# # Make QGIS File

# %%
# Create Dataframe with TP, TN, FP, FN and gridnumber
qgis_koppel_train = []
qgis_koppel_test = []
qgis_koppel_val1 = []
qgis_koppel_val2 = []
qgis_train = pd.DataFrame(train.index,columns=["id"])
qgis_test = pd.DataFrame(test.index,columns=["id"])
qgis_val1 = pd.DataFrame(validation["c28992r100"],columns=["c28992r100"])
qgis_val2 = pd.DataFrame(validation2["c28992r100"],columns=["c28992r100"])

for y, yt in zip(y_train, pr_xgb):
    if y == 0 and yt == 0:
        qgis_koppel_train.append("TN")
    if y == 0 and yt == 1:
        qgis_koppel_train.append("FN")
    if y == 1 and yt == 0:
        qgis_koppel_train.append("FP")
    if y == 1 and yt == 1:
        qgis_koppel_train.append("TP")

for y, yt in zip(y_test.to_numpy(), p_xgb):
    if y == 0 and yt == 0:
        qgis_koppel_test.append("TN")
    if y == 0 and yt == 1:
        qgis_koppel_test.append("FN")
    if y == 1 and yt == 0:
        qgis_koppel_test.append("FP")
    if y == 1 and yt == 1:
        qgis_koppel_test.append("TP")
        
for y, yt in zip(y_val1.to_numpy(), pre_xgb):
    if y == 0 and yt == 0:
        qgis_koppel_val1.append("TN")
    if y == 0 and yt == 1:
        qgis_koppel_val1.append("FN")
    if y == 1 and yt == 0:
        qgis_koppel_val1.append("FP")
    if y == 1 and yt == 1:
        qgis_koppel_val1.append("TP")

for y, yt in zip(y_val2.to_numpy(), pred_xgb):
    if y == 0 and yt == 0:
        qgis_koppel_val2.append("TN")
    if y == 0 and yt == 1:
        qgis_koppel_val2.append("FN")
    if y == 1 and yt == 0:
        qgis_koppel_val2.append("FP")
    if y == 1 and yt == 1:
        qgis_koppel_val2.append("TP")

qgis_train["label"] = pd.Series(qgis_koppel_train)
qgis_test["label"] = pd.Series(qgis_koppel_test)
qgis_val1["label"] = pd.Series(qgis_koppel_val1)
qgis_val2["label"] = pd.Series(qgis_koppel_val2)

qgis_train.to_csv("New Figures\qgistrainxgbSZ.csv", index=False)
qgis_test.to_csv("New Figures\qgistestxgbSZ.csv", index=False)
qgis_val1.to_csv("New Figures\qgisval1xgbSZ.csv", index=False)
qgis_val2.to_csv("New Figures\qgisval2xgbSZ.csv", index=False)
