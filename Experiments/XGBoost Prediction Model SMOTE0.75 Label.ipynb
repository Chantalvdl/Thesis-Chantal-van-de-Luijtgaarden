# %%
# Import packages
import pandas as pd
import numpy as np
import math
import time

import xgboost as xgb
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline

from hyperopt import *
import pyspark 
import mlflow

import seaborn as sns

import warnings

# %%
# Import Data
# Import Data
train = pd.read_csv("..\\Predictive Models\\Datasets\\17SMOTE_0.75_newlabel.csv", delimiter=',')
test = pd.read_csv("..\\Predictive Models\\Datasets\\172_newlabel.csv", delimiter=',')
validation = pd.read_csv("..\\Data\\final_18_new.csv", delimiter=',')
validation2 = pd.read_csv("..\\Data\\final_19_new.csv", delimiter=',')

# Define X and y
X_train = (train.drop(labels=["label"], axis=1))
y_train = train[["label"]]
X_test = test.drop(labels=["label","c28992r100","row","column","WONING"], axis=1)
y_test =test[["label"]]

X_val1 = validation.drop(labels=["label","c28992r100","row","column","WONING"], axis=1)
y_val1 = validation[["label"]]
X_val2 = validation2.drop(labels=["label","c28992r100","row","column","WONING"], axis=1)
y_val2 = validation2[["label"]]

# Make column list
columns = X_train.columns

X_train = X_train.to_numpy()
y_train = y_train.to_numpy()

# %% [markdown]
# # Define hyperopt settings

# %%
import warnings
warnings.filterwarnings("ignore")

start_time = time.time()
# Define objectives
def objective(params):
    classifier_type = params['type']
    del params['type']
    if classifier_type == 'XGB':
        clf = xgb.XGBClassifier(**params,
                                eval_metric='auc')
    else:
        return 0
    classifier = clf
    print(classifier)
    classifier.fit(X_train, y_train)
    pr_xgb = classifier.predict(X_train)
    accuracy = accuracy_score(y_train,pr_xgb)
    f1 = f1_score(y_train,pr_xgb)
    recall = recall_score(y_train,pr_xgb)
    print(accuracy, f1, recall)

    # Because fmin() tries to minimize the objective, this function must return the negative accuracy. 
    return {'loss': -accuracy, 'status': STATUS_OK}

# Define search space
space = hp.choice('classifier_type', [
        {
        "type": 'XGB',
        'eta':hp.choice('eta',np.arange(0.01,0.5,0.05)),
        'max_depth':hp.choice('max_depth',range(2,15)),
        'min_child_weight':hp.choice('min_child_weight',range(1,15)),
        'max_leaves':hp.choice('max_leaves',range(2,15)),
        'subsample':hp.choice('subsample', np.arange(0.1, 0.5, 0.05))}
])
    
with mlflow.start_run():
    best = fmin(
    fn=objective, 
    space=space,
    algo=tpe.suggest,
    max_evals=30, 
    verbose = 1,
    return_argmin=False)
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.11, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=2,
#               max_leaves=10, min_child_weight=9, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.25000000000000006, tree_method=None,
#               validate_parameters=None, ...)
# 0.890644663336934
# 0.8542006811208787
# 0.7474660089589112
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.46, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=13,
#               max_leaves=5, min_child_weight=14, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9811356741282624
# 0.9775288294734786
# 0.957397340609156
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.01, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=11,
#               max_leaves=6, min_child_weight=1, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9131631390751614
# 0.8873977782811496
# 0.7984037000220437
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.060000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=5, max_leaves=5,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.15000000000000002, tree_method=None,
#               validate_parameters=None, ...)
# 0.9285105685144187
# 0.9090822535160182
# 0.833956519749949
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.11, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=13,
#               max_leaves=13, min_child_weight=10, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.30000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9776276902564321
# 0.9732021803787266
# 0.9478977336533143
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.01, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=2,
#               max_leaves=13, min_child_weight=7, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.7096359040723272
# 0.49113764299414586
# 0.32695867005502616
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.11, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=9,
#               max_leaves=6, min_child_weight=12, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9744476886165211
# 0.9692765029008896
# 0.9404902030104271
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.16000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=12, max_leaves=2,
#               min_child_weight=14, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.20000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9780376680463311
# 0.9737051588766698
# 0.948816916287833
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.01, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=14,
#               max_leaves=8, min_child_weight=11, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.1, tree_method=None, validate_parameters=None, ...)
# 0.9342609526457828
# 0.9170941592745291
# 0.8483972532660098
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.41000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=10,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9866097688794773
# 0.984140723632264
# 0.9694132620169612
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.060000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=3, max_leaves=11,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.8987176607736815
# 0.8663656247795104
# 0.7660617807187925
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=9,
#               min_child_weight=8, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.9819039368562903
# 0.9784397259517569
# 0.9581002449767293
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.01, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=10,
#               max_leaves=2, min_child_weight=5, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.25000000000000006, tree_method=None,
#               validate_parameters=None, ...)
# 0.9089760180818031
# 0.8813537269079478
# 0.7888583418943481
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.16000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=14, max_leaves=11,
#               min_child_weight=10, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.25000000000000006, tree_method=None,
#               validate_parameters=None, ...)
# 0.9785225113456897
# 0.9743013328157626
# 0.9499773323739451
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.060000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=12,
#               min_child_weight=8, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9738451995165827
# 0.9685348201361711
# 0.9392549213703724
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.46, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=10,
#               max_leaves=14, min_child_weight=6, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.1, tree_method=None, validate_parameters=None, ...)
# 0.9722266785025472
# 0.9669721231237532
# 0.9486547075876239
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.060000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=5, max_leaves=6,
#               min_child_weight=6, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.924835028502369
# 0.9039501437285603
# 0.8252970706772421
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.11, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=7,
#               max_leaves=13, min_child_weight=9, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.20000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9702302649169527
# 0.9640285600439384
# 0.930795113774846
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=3, max_leaves=3,
#               min_child_weight=2, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.3500000000000001, tree_method=None,
#               validate_parameters=None, ...)
# 0.9695743004531145
# 0.9632061460329505
# 0.9292478923266967
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.11, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=13,
#               max_leaves=8, min_child_weight=2, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.40000000000000013, tree_method=None,
#               validate_parameters=None, ...)
# 0.9786651123160893
# 0.974475226959142
# 0.9502684761948335
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.41000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=4, max_leaves=9,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.976274763549766
# 0.9715351351813752
# 0.9447284252030728
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.26, eval_metric='auc', gamma=None,
#               gpu_id=None, importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=6,
#               max_leaves=10, min_child_weight=13, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.9767738669461645
# 0.9721500265034283
# 0.9458722044994198
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.41000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=8, max_leaves=7,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.9793175117556675
# 0.975281789306173
# 0.952056931094576
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=9,
#               min_child_weight=8, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.15000000000000002, tree_method=None,
#               validate_parameters=None, ...)
# 0.9776882956688521
# 0.9733904484528959
# 0.9522025030050202
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.31000000000000005,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=9, max_leaves=10,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.30000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.978766715507499
# 0.9746057192559084
# 0.9507301471108135
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.41000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=7, max_leaves=4,
#               min_child_weight=8, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.9785332064184696
# 0.974314677723107
# 0.9500106059534752
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.21000000000000002,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=13, max_leaves=9,
#               min_child_weight=8, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.979474372823107
# 0.9754666450770303
# 0.95213595584596
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=6, max_leaves=7,
#               min_child_weight=7, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.30000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9775581722833624
# 0.9731167871678034
# 0.9477396841505463
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.41000000000000003,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=12, max_leaves=10,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.20000000000000004, tree_method=None,
#               validate_parameters=None, ...)
# 0.9792622538796376
# 0.9753728784139067
# 0.9582208617025259
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None,
#               enable_categorical=False, eta=0.36000000000000004,
#               eval_metric='auc', gamma=None, gpu_id=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None,
#               max_delta_step=None, max_depth=8, max_leaves=12,
#               min_child_weight=12, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, reg_alpha=None,
#               reg_lambda=None, scale_pos_weight=None,
#               subsample=0.45000000000000007, tree_method=None,
#               validate_parameters=None, ...)
# 0.9787328477770291
# 0.9745589774973505
# 0.950451480882249
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 30/30 [3:44:30<00:00, 449.03s/trial, best loss: -0.9866097688794773]
# --- 13472.902026891708 seconds ---

# %%
# Results
print(best)
# Out:
# {'eta': 0.41000000000000003, 'max_depth': 13, 'max_leaves': 10, 'min_child_weight': 3, 'subsample': 0.40000000000000013, 'type': 'XGB'}

# %%
# Fitting Randomforest to the Training set
classifier = xgb.XGBClassifier(eta = best['eta'],
                            max_depth = best['max_depth'],
                            min_child_weight = int(best['min_child_weight']),
                            max_leaves= int(best['max_leaves']),
                            subsample = best['subsample'],
                           n_jobs = -1,)
classifier.fit(X_train, y_train)
pr_xgb = classifier.predict(X_train)
accuracy = accuracy_score(y_train,pr_xgb)
f1 = f1_score(y_train,pr_xgb)
recall = recall_score(y_train,pr_xgb)
print(accuracy, f1, recall)
print(roc_auc_score(y_train, classifier.predict_proba(X_train)[:, 1]))
# Out:
# [05:11:33] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9866097688794773 0.984140723632264 0.9694132620169612
# 0.9987360075007725

# %% [markdown]
# # Results

# %%
# Make confusion matrixes, accuracy, recall and f1 score for testset
p_xgb = classifier.predict(X_test)
print("Accuracy:" + str(classifier.score(X_test, y_test)))
print("F1:" + str(f1_score(y_test,p_xgb)))
print("Recall:" + str(recall_score(y_test,p_xgb)))
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test,p_xgb),display_labels=classifier.classes_).plot()
plt.savefig('con_test_xgb_smote0.75.png', dpi=300)
plt.show()

# Make confusion matrixes, accuracy, recall and f1 score for validationset 1
pre_xgb = classifier.predict(X_val1)
print("Accuracy:" + str(classifier.score(X_val1, y_val1)))
print("F1:" + str(f1_score(y_val1,pre_xgb)))
print("Recall:" + str(recall_score(y_val1,pre_xgb)))
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_val1,pre_xgb),display_labels=classifier.classes_).plot()
plt.savefig('con_val_xgb_smote0.75.png', dpi=300)
plt.show()

# Make confusion matrixes, accuracy, recall and f1 score for validationset 2
pred_xgb = classifier.predict(X_val2)
print("Accuracy:" + str(classifier.score(X_val2, y_val2)))
print("F1:" + str(f1_score(y_val2, pred_xgb)))
print("Recall:" + str(recall_score(y_val2, pred_xgb)))
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_val2, pred_xgb),display_labels=classifier.classes_).plot()
plt.savefig('con_val2_xgb_smote0.75.png', dpi=300)
plt.show()
# Out:
# Accuracy:0.9581583154928051
# F1:0.007712082262210797
# Recall:0.004398826979472141
# Accuracy:0.6025694302028128
# F1:0.06245902161112702
# Recall:0.3909786420146637
# Accuracy:0.5105165555794453
# F1:0.03926760949723323
# Recall:0.4797628254704821

# %%
print(roc_auc_score(y_test, classifier.predict_proba(X_test)[:, 1]))
print(roc_auc_score(y_val1, classifier.predict_proba(X_val1)[:, 1]))
print(roc_auc_score(y_val2, classifier.predict_proba(X_val2)[:, 1]))
# Out:
# 0.521899070622936
# 0.5014691108209052
# 0.4931597333790428

# %%
# Create feature importance plot
feat_importances = pd.Series(classifier.feature_importances_, index=columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.savefig('import_xgb_smote0.75.png', dpi=300, bbox_inches = "tight")

# %% [markdown]
# # Make QGIS File

# %%
# Create Dataframe with TP, TN, FP, FN and gridnumber
qgis_koppel_train = []
qgis_koppel_test = []
qgis_koppel_val1 = []
qgis_koppel_val2 = []
qgis_train = pd.DataFrame(train.index,columns=["id"])
qgis_test = pd.DataFrame(test.index,columns=["id"])
qgis_val1 = pd.DataFrame(validation["c28992r100"],columns=["c28992r100"])
qgis_val2 = pd.DataFrame(validation2["c28992r100"],columns=["c28992r100"])

for y, yt in zip(y_train, pr_xgb):
    if y == 0 and yt == 0:
        qgis_koppel_train.append("TN")
    if y == 0 and yt == 1:
        qgis_koppel_train.append("FN")
    if y == 1 and yt == 0:
        qgis_koppel_train.append("FP")
    if y == 1 and yt == 1:
        qgis_koppel_train.append("TP")

for y, yt in zip(y_test.to_numpy(), p_xgb):
    if y == 0 and yt == 0:
        qgis_koppel_test.append("TN")
    if y == 0 and yt == 1:
        qgis_koppel_test.append("FN")
    if y == 1 and yt == 0:
        qgis_koppel_test.append("FP")
    if y == 1 and yt == 1:
        qgis_koppel_test.append("TP")
        
for y, yt in zip(y_val1.to_numpy(), pre_xgb):
    if y == 0 and yt == 0:
        qgis_koppel_val1.append("TN")
    if y == 0 and yt == 1:
        qgis_koppel_val1.append("FN")
    if y == 1 and yt == 0:
        qgis_koppel_val1.append("FP")
    if y == 1 and yt == 1:
        qgis_koppel_val1.append("TP")

for y, yt in zip(y_val2.to_numpy(), pred_xgb):
    if y == 0 and yt == 0:
        qgis_koppel_val2.append("TN")
    if y == 0 and yt == 1:
        qgis_koppel_val2.append("FN")
    if y == 1 and yt == 0:
        qgis_koppel_val2.append("FP")
    if y == 1 and yt == 1:
        qgis_koppel_val2.append("TP")

qgis_train["label"] = pd.Series(qgis_koppel_train)
qgis_test["label"] = pd.Series(qgis_koppel_test)
qgis_val1["label"] = pd.Series(qgis_koppel_val1)
qgis_val2["label"] = pd.Series(qgis_koppel_val2)

qgis_train.to_csv("qgistrainxgbS75.csv", index=False)
qgis_test.to_csv("qgistestxgbS75.csv", index=False)
qgis_val1.to_csv("qgisval1xgbS75.csv", index=False)
qgis_val2.to_csv("qgisval2xgbS75.csv", index=False)
