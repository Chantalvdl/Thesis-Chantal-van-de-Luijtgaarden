# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
from scipy.spatial.distance import pdist
from sklearn.manifold._t_sne import _joint_probabilities
from scipy import linalg
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import squareform
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
palette = sns.color_palette("bright", 2)

# %%
# Import Data
train = pd.read_csv("..\\Predictive Models\\Datasets\\17zScore.csv", delimiter=',')

# Define X and y
X = (train.drop(labels=["label","c28992r100", "row", "column"], axis=1))
y = train[["label"]]


# Make column list
columns = X.columns

X = X.to_numpy()
y = y.to_numpy()

# %%
tsne = TSNE(n_components=2)
X_embedded = tsne.fit_transform(X)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y
# Out:
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df = pd.DataFrame(columns=['X_em','Y_em'])
df["X_em"] = X_em
df["Y_em"] = Y_em

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, learning_rate = 10)
X_embedded = tsne.fit_transform(X)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame(columns=['X','Y'])
df["X_em"] = X_em
df["Y_em"] = Y_em
# Out:
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, learning_rate = 75)
X_embedded = tsne.fit_transform(X)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame(columns=['X','Y'])
df["X_em"] = X_em
df["Y_em"] = Y_em
# Out:
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, learning_rate = 150)
X_embedded = tsne.fit_transform(X)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame(columns=['X','Y'])
df["X_em"] = X_em
df["Y_em"] = Y_em
# Out:
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, learning_rate = 800)
X_embedded = tsne.fit_transform(X)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame(columns=['X','Y'])
df["X_em"] = X_em
df["Y_em"] = Y_em
# Out:
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2)
# Define X and y
X_1 = (train.drop(labels=["label","c28992r100", "row", "column", 'sur_green', 'sur_water', 'sur_road', 'sur_other'], axis=1))
X_1 = X_1.to_numpy()

X_embedded_3 = tsne.fit_transform(X_1)

X_em = X_embedded_3[:,0].ravel()
Y_em = X_embedded_3[:,1].ravel()

y = y.flatten()
y

df_3 = pd.DataFrame()
df_3["X_em"] = X_em
df_3["Y_em"] = Y_em

# %%
sns.scatterplot(data = df_3, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, init="pca", n_iter = 250)
X_1 = (train.drop(labels=["label","c28992r100", "row", "column", 'sur_green', 'sur_water', 'sur_road', 'sur_other'], axis=1))
X_1 = X_1.to_numpy()
X_embedded_6 = tsne.fit_transform(X_1)

X_em = X_embedded_6[:,0].ravel()
Y_em = X_embedded_6[:,1].ravel()

y = y.flatten()
y

df_6 = pd.DataFrame()
df_6["X_em"] = X_em
df_6["Y_em"] = Y_em

# %%
sns.scatterplot(data = df_6, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, init="pca", perplexity=5, n_iter = 250)
X_embedded = tsne.fit_transform(X_1)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame()
df["X_em"] = X_em
df["Y_em"] = Y_em

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, init="pca", perplexity=50, n_iter = 500)
X_embedded = tsne.fit_transform(X_1)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame()
df["X_em"] = X_em
df["Y_em"] = Y_em

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, init="pca", perplexity=25, n_iter = 500)
X_embedded = tsne.fit_transform(X_1)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame()
df["X_em"] = X_em
df["Y_em"] = Y_em

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, init="pca", perplexity=5, n_iter = 250)
X_embedded = tsne.fit_transform(X_1)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame()
df["X_em"] = X_em
df["Y_em"] = Y_em

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, init="pca", perplexity=50, n_iter = 500)
X_embedded = tsne.fit_transform(X)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame()
df["X_em"] = X_em
df["Y_em"] = Y_em
# Out:
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, init="pca", perplexity=25, n_iter = 750)
X_embedded = tsne.fit_transform(X)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame()
df["X_em"] = X_em
df["Y_em"] = Y_em
# Out:
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, perplexity=25, n_iter = 2500)
X_embedded = tsne.fit_transform(X_1)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame()
df["X_em"] = X_em
df["Y_em"] = Y_em

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, perplexity=50, n_iter = 2500)
X_embedded = tsne.fit_transform(X)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame()
df["X_em"] = X_em
df["Y_em"] = Y_em
# Out:
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)

# %%
tsne = TSNE(n_components=2, perplexity=50, n_iter = 5000)
X_1 = (train.drop(labels=["label","c28992r100", "row", "column", "('Fundering',)","('P_HINK_HH',)", "('P_LINK_HH',)"], axis=1))
X_1 = X_1.to_numpy()
X_embedded = tsne.fit_transform(X_1)

X_em = X_embedded[:,0].ravel()
Y_em = X_embedded[:,1].ravel()

y = y.flatten()
y

df = pd.DataFrame()
df["X_em"] = X_em
df["Y_em"] = Y_em
# Out:
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\s169096\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-42b6e2bec90a> in <module>
#       2 X_1 = (train.drop(labels=["label","c28992r100", "row", "column", "('Fundering',)","('P_HINK_HH',)", "('P_LINK_HH',)"], axis=1))
#       3 X_1 = X_1.to_numpy()
# ----> 4 X_embedded = tsne.fit_transform(X_1)
#       5
#       6 X_em = X_embedded[:,0].ravel()
#
# ~\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py in fit_transform(self, X, y)
# ...

# %%
sns.scatterplot(data = df, x = X_em, y = Y_em, hue=y, legend='full', palette=palette)
